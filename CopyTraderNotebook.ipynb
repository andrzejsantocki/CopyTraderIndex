# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/andrzejsantocki/CopyTraderIndex.git
# Out:
# fatal: destination path 'CopyTraderIndex' already exists and is not an empty directory.

# %%
import shutil

# Example of copying a file from Google Drive to the cloned repo
shutil.copy('/content/drive/MyDrive/Colab Notebooks/your_notebook.ipynb', '/content/CopyTraderIndex/your_notebook.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-3062af2abfcf> in <cell line: 4>()
#       2
#       3 # Example of copying a file from Google Drive to the cloned repo
# ----> 4 shutil.copy('/content/drive/MyDrive/Colab Notebooks/your_notebook.ipynb', '/content/CopyTraderIndex/your_notebook.ipynb')
#
# /usr/lib/python3.10/shutil.py in copy(src, dst, follow_symlinks)
#     415     if os.path.isdir(dst):
#     416         dst = os.path.join(dst, os.path.basename(src))
# --> 417     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418     copymode(src, dst, follow_symlinks=follow_symlinks)
#     419     return dst
#
# /usr/lib/python3.10/shutil.py in copyfile(src, dst, follow_symlinks)
#     252         os.symlink(os.readlink(src), dst)
#     253     else:
# --> 254         with open(src, 'rb') as fsrc:
#     255             try:
# ...

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# MagicParticles.ipynb  test_file.ipynb
